# %% [markdown]
# # ICP01 Jupyter Install
# ## YESWANTH KUMAR LEKKALA

# %% [markdown]
# ![IMG-20220814-WA0016%20%281%29.jpg](attachment:IMG-20220814-WA0016%20%281%29.jpg)
#
# Myself Yeswanth kumar Lekkala pursuing Masters in Business Analytics and information systems at University of South Florida.I have an work experience of 26 months in the Offshore industry as a Mechanical Engineer.

# %%
print("Hello World")
# Out:
# Hello World
